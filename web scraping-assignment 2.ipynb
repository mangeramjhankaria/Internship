# %%
# !pip install selenium

# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings("ignore")
import time

# %% [markdown]
# # Question 1.-

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
designation=driver.find_element(By.CLASS_NAME,"searchBarInput")
designation.send_keys('Data Analyst')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap__Cb75F")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# scraping Job title from the givan page
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
# scraping job location from the givan page
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
# scraping Company name from the givan page
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)
    
# scraping job Experience from the givan page
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    experience=i.text
    experience_required.append(experience)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 20 20 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                Title        Location  \
# 0                               Data Analyst Vacancy  Bangalore\n+14
# 1                               Data Analyst Vacancy  Bangalore\n+14
# 2                              Clinical Data Analyst   Bangalore\n+4
# 3                    Data Analyst Urgent Recruitment  Bangalore\n+14
# 4                    Data Analyst Urgent Recruitment  Bangalore\n+14
# 5                    Data Analyst Urgent Recruitment  Bangalore\n+14
# 6                                     Data Analyst 1       Bangalore
# 7                              Clinical Data Analyst   Bangalore\n+6
# 8                            Hiring For Data Analyst  Bangalore\n+14
# 9                                       Data Analyst   Bangalore\n+9
# 10                                      Data Analyst       Bangalore
# 11                          Apply Now a Data Analyst       Bangalore
# 12                      Urgently need a Data Analyst       Bangalore
# ...

# %%
df.head(10)
# Out:
#                              Title        Location             Company_name  \
# 0             Data Analyst Vacancy  Bangalore\n+14        divya interprises
# 1             Data Analyst Vacancy  Bangalore\n+14        divya interprises
# 2            Clinical Data Analyst   Bangalore\n+4          quiscon biotech
# 3  Data Analyst Urgent Recruitment  Bangalore\n+14        divya interprises
# 4  Data Analyst Urgent Recruitment  Bangalore\n+14        divya interprises
# 5  Data Analyst Urgent Recruitment  Bangalore\n+14        divya interprises
# 6                   Data Analyst 1       Bangalore                merck ltd
# 7            Clinical Data Analyst   Bangalore\n+6            techno endura
# 8          Hiring For Data Analyst  Bangalore\n+14        divya interprises
# 9                     Data Analyst   Bangalore\n+9  v-tech data outsourcing
#
#    Experience
# 0  0 to 4 Yrs
# 1  0 to 4 Yrs
# 2  0 to 2 Yrs
# 3  0 to 4 Yrs
# 4  0 to 4 Yrs
# 5  0 to 4 Yrs
# 6  1 to 3 Yrs
# ...

# %% [markdown]
# # Question 2.-

# %%
driver = webdriver.Chrome()

# %%
# Opening the naukri page on automated chrome brower
driver.get("https://www.shine.com/")

# %%
# entering designation and location as required in the question-

designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys("Bangalore")

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap__Cb75F")
search.click()

# %%
job_title=[]
job_location=[]

# %%
# scraping Job title from the givan page
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
# scraping job location from the givan page
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)

# %%
print(len(job_title),len(job_location))
# Out:
# 20 20

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location})
df
# Out:
#                                            Title        Location
# 0                         Data Scientist Vacancy  Bangalore\n+14
# 1              Data Scientist Urgent Recruitment  Bangalore\n+14
# 2                      Data Scientist- Bangalore       Bangalore
# 3                        Data Scientist AI ML CV       Bangalore
# 4                       Data Scientist AI ML NLP       Bangalore
# 5                       Data Scientist-Bangalore       Bangalore
# 6                             Phd Data Scientist       Bangalore
# 7                      Hiring For Data Scientist  Bangalore\n+14
# 8                                 Data Scientist       Bangalore
# 9               Staff Data Scientist & Team Lead       Bangalore
# 10                                Data scientist   Bangalore\n+8
# 11             Data Scientist Associate Sr - NLP       Bangalore
# 12                    Data Scientist - Bangalore       Bangalore
# ...

# %%
df.head(10)
# Out:
#                                Title        Location
# 0             Data Scientist Vacancy  Bangalore\n+14
# 1  Data Scientist Urgent Recruitment  Bangalore\n+14
# 2          Data Scientist- Bangalore       Bangalore
# 3            Data Scientist AI ML CV       Bangalore
# 4           Data Scientist AI ML NLP       Bangalore
# 5           Data Scientist-Bangalore       Bangalore
# 6                 Phd Data Scientist       Bangalore
# 7          Hiring For Data Scientist  Bangalore\n+14
# 8                     Data Scientist       Bangalore
# 9   Staff Data Scientist & Team Lead       Bangalore

# %% [markdown]
# # Question 3.-

# %%
driver = webdriver.Chrome()

# %%
# Opening the naukri page on automated chrome brower
driver.get("https://www.shine.com/")

# %%
# entering designation and location as required in the question-

designation=driver.find_element(By.CLASS_NAME,"form-control  ")
designation.send_keys('Data Scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys("Delhi-ncr Region")

# %%
search=driver.find_element(By.CLASS_NAME,"searchForm_btnWrap_advance__VYBHN")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# scraping Job title from the givan page
title_tags=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]')
for i in title_tags:
    title=i.text
    job_title.append(title)
    
# scraping job location from the givan page
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location_tags:
    location=i.text
    job_location.append(location)
    
# scraping Company name from the givan page
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')
for i in company_tags:
    company=i.text
    company_name.append(company)
    
# scraping job Experience from the givan page
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tags:
    experience=i.text
    experience_required.append(experience)

# %%
    
#scraping job salary from the givan page
salary_tags=driver.find_elements(By.XPATH,'p')
for i in salary_tags:
    salary=i.text
    salary_filter.append(salary)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 40 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                        Title   Location  \
# 0                  Data Scientist- Faridabad  Faridabad
# 1                  Data Scientist- Ghaziabad  Ghaziabad
# 2                      Data Scientist- Noida      Noida
# 3                      Data Scientist- Delhi      Delhi
# 4                   Data Scientist-Faridabad  Faridabad
# 5                   Data Scientist-Ghaziabad  Ghaziabad
# 6                       Data Scientist-Noida      Noida
# 7                       Data Scientist-Delhi      Delhi
# 8                             Data scientist  Delhi\n+8
# 9                             Data Scientist  Delhi\n+6
# 10        Urgently need Data Scientist_Noida      Noida
# 11     Urgently need Data Scientist_Gurugram   Gurugram
# 12        Urgently need Data Scientist_Delhi      Delhi
# 13                      Data Scientist Noida      Noida
# 14                   Data Scientist Gurugram   Gurugram
# 15  Needed for the post Data Scientist_Delhi      Delhi
# ...

# %%
df.head(10)
# Out:
#                        Title   Location  \
# 0  Data Scientist- Faridabad  Faridabad
# 1  Data Scientist- Ghaziabad  Ghaziabad
# 2      Data Scientist- Noida      Noida
# 3      Data Scientist- Delhi      Delhi
# 4   Data Scientist-Faridabad  Faridabad
# 5   Data Scientist-Ghaziabad  Ghaziabad
# 6       Data Scientist-Noida      Noida
# 7       Data Scientist-Delhi      Delhi
# 8             Data scientist  Delhi\n+8
# 9             Data Scientist  Delhi\n+6
#
#                              Company_name   Experience
# 0                       the fashion cosmo   0 to 3 Yrs
# 1                       the fashion cosmo   0 to 3 Yrs
# 2                       the fashion cosmo   0 to 3 Yrs
# 3                       the fashion cosmo   0 to 3 Yrs
# 4                       shiva hr services   0 to 3 Yrs
# 5                       shiva hr services   0 to 3 Yrs
# 6                       shiva hr services   0 to 3 Yrs
# 7                       shiva hr services   0 to 3 Yrs
# ...

# %%
# Salary tag is not see

# %%
print(len(salary_filter))
# Out:
# 1

# %% [markdown]
# # Question 4.-

# %%
driver = webdriver.Chrome()

# %%
# Opening the flipkart page on automated chrome brower
driver.get("https://www.flipkart.com/")

# %%
# entering designation and location as required in the question-

designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys('sunglasses')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand_name=[]
product_description=[]
sunglasses_price=[]

# %%
# scraping brand name from the givan page
name_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in name_tags:
    name=i.text
    brand_name.append(name)
    
# scraping product description from the givan page
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags:
    description=i.text
    product_description.append(description)
    
# scraping sunglasses price from the givan page
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags:
    price=i.text
    sunglasses_price.append(price)

# %%
# scraping brand name from the givan page
start=0
end=3
for page in range(start,end):
    name_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name_tags:
        name=i.text
        brand_name.append(name)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)
    

# scraping product description from the givan page
start=0
end=3
for page in range(start,end):
    description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description_tags:
        description=i.text
        product_description.append(description)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)
    

# scraping sunglasses price from the givan page
start=0
end=3
for page in range(start,end):
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        price=i.text
        sunglasses_price.append(price)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brand_name),len(product_description),len(sunglasses_price))
# Out:
# 120 120 120

# %%
import pandas as pd
df=pd.DataFrame({'Brand_name':brand_name,'Product_description':product_description,'Sunglasses_price':sunglasses_price})
df
# Out:
#         Brand_name                                Product_description  \
# 0        ROYAL SON  UV Protection Wayfarer, Sports, Spectacle , Re...
# 1    VINCENT CHASE  UV Protection Retro Square Sunglasses (Free Size)
# 2             SRPM    UV Protection, Gradient Aviator Sunglasses (57)
# 3         Fastrack   Polarized, UV Protection Aviator Sunglasses (59)
# 4           GANSTA                       Encoder Rectangular Sunglass
# ..             ...                                                ...
# 115   Singco India           UV Protection Over-sized Sunglasses (58)
# 116         GANSTA      UV Protection Wayfarer Sunglasses (Free Size)
# 117         PERKEY  Polarized, UV Protection Retro Square Sunglass...
# 118        Ray-Ban          UV Protection Rectangular Sunglasses (60)
# 119        Ray-Ban             UV Protection Wayfarer Sunglasses (53)
#
#     Sunglasses_price
# 0               ₹594
# 1               ₹489
# 2             ₹3,669
# 3               ₹135
# ...

# %%
df.head(100)
# Out:
#        Brand_name                                Product_description  \
# 0       ROYAL SON  UV Protection Wayfarer, Sports, Spectacle , Re...
# 1   VINCENT CHASE  UV Protection Retro Square Sunglasses (Free Size)
# 2            SRPM    UV Protection, Gradient Aviator Sunglasses (57)
# 3        Fastrack   Polarized, UV Protection Aviator Sunglasses (59)
# 4          GANSTA                       Encoder Rectangular Sunglass
# ..            ...                                                ...
# 95        Ray-Ban          UV Protection Rectangular Sunglasses (53)
# 96          NuVew  UV Protection Over-sized, Retro Square Sunglas...
# 97  VINCENT CHASE   UV Protection Rectangular Sunglasses (Free Size)
# 98         PIRASO     Polarized, UV Protection Round Sunglasses (48)
# 99        Ray-Ban                   Gradient Aviator Sunglasses (60)
#
#    Sunglasses_price
# 0              ₹594
# 1              ₹489
# 2            ₹3,669
# 3              ₹135
# 4              ₹360
# ...

# %% [markdown]
# # Question 5.-

# %%
driver = webdriver.Chrome()

# %%
#  Opening the given link
driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&marketplace=FLIPKART")

# %%
#Step 2: Scrapping all the required data

rating = []
summary = []
full_review =[]

#Defining start and end of the review section
start = 0
end = 10

#Looping to the review section
for review in range(start,end):
    
    #Extracting rating
    rating_tag = driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tag:
        rating.append(i.text)
        
    #Extracting Summary
    summary_tag = driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')
    for i in summary_tag:
        summary.append(i.text)
    
    #Extracting Full Review
    review_tag = driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]')
    for i in review_tag:
        full_review.append(i.text)
        
    # Find the next button and click on it
    nextbutton = driver.find_element(By.CLASS_NAME,"_1LKTO3")
    nextbutton.click()
    # Wait for 3 seconds for the next page to load
    time.sleep(3)

# %%
print(len(rating),len(summary),len(full_review))
# Out:
# 100 100 100

# %%
df = pd.DataFrame({'Rating':rating, 'Review_Summary':summary, 'Full review':full_review})
df
# Out:
#    Rating        Review_Summary  \
# 0       5    Highly recommended
# 1       5      Perfect product!
# 2       5   Best in the market!
# 3       5        Classy product
# 4       5     Worth every penny
# ..    ...                   ...
# 95      4  Good quality product
# 96      5             Brilliant
# 97      5     Terrific purchase
# 98      5             Fabulous!
# 99      5         Great product
#
#                                           Full review
# 0   Awesome Battery Life...Camera clarity is too g...
# 1                                        Photos super
# 2                                         Good Camera
# 3   Camera is awesome\nBest battery backup\nA perf...
# 4   Feeling awesome after getting the delivery of ...
# ..                                                ...
# 95                                            Awesome
# 96                           very good camera quality
# 97                                 Value for money 🖤🖤
# ...

# %% [markdown]
# # Question 6.-

# %%
driver = webdriver.Chrome()

# %%
# Opening the flipkart page on automated chrome brower
driver.get("https://www.flipkart.com/")

# %%
# entering designation and location as required in the question-
designation=driver.find_element(By.CLASS_NAME,"_3704LK")
designation.send_keys('sneakers')

# %%
search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
search.click()

# %%
brand_name=[]
product_description=[]
sneakers_price=[]

# %%
# scraping brand name from the givan page
name_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in name_tags:
    name=i.text
    brand_name.append(name)
    
# scraping product description from the givan page
description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description_tags:
    description=i.text
    product_description.append(description)
    
# scraping sunglasses price from the givan page
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags:
    price=i.text
    sneakers_price.append(price)

# %%
print(len(brand_name),len(product_description),len(sneakers_price))
# Out:
# 40 40 40

# %%
import pandas as pd
df=pd.DataFrame({'Brand_name':brand_name,'Product_description':product_description,'Sneakers_price':sneakers_price})
df
# Out:
#                Brand_name                                Product_description  \
# 0                  BRUTON  Synthetic Leather |Lightweight|Comfort|Summer|...
# 1                  BRUTON  Combo Pack Of 2 Men’s Casual Shoes Sneakers Fo...
# 2                URBANBOX  Trending Stylish Casual Outdoor Sneakers Shoes...
# 3                  Layasa                                   Sneakers For Men
# 4                RED TAPE                                   Sneakers For Men
# 5                    aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...
# 6               Ego by NS                                   Sneakers For Men
# 7                  BRUTON  Combo Pack Of 2 Casual Shoes for mens Sneakers...
# 8                RED TAPE  Sneaker Casual Shoes For Men | Soft Cushion In...
# 9         U.S. POLO ASSN.                         MOORE 3.0 Sneakers For Men
# 10                 BRUTON    !Combo Pack Of 2 Casual Shoes! Sneakers For Men
# ...

# %%
# scraping brand name from the givan page
start=0
end=3
for page in range(start,end):
    name_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
    for i in name_tags:
        name=i.text
        brand_name.append(name)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)
    

# scraping product description from the givan page
start=0
end=3
for page in range(start,end):
    description_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
    for i in description_tags:
        description=i.text
        product_description.append(description)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)
    

# scraping sneakers price from the givan page
start=0
end=3
for page in range(start,end):
    price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
    for i in price_tags:
        price=i.text
        sneakers_price.append(price)
    next_button=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
    next_button.click()
    time.sleep(3)

# %%
print(len(brand_name),len(product_description),len(sneakers_price))
# Out:
# 160 158 160

# %% [markdown]
# # Question 7.-

# %%
driver = webdriver.Chrome()

# %%
# Opening the amazon page on automated chrome brower
driver.get("https://www.amazon.in/")

# %%
# entering designation as required in the question-
designation=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
designation.send_keys('Leptop')

# %%
search=driver.find_element(By.ID,"nav-search-submit-button")
search.click()

# %%
# Applying Filter
filter = driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[5]/ul[6]/span[10]/li")
filter.click()

# %%
#Creating empty list
title = []
rating = []
price = []

# Extracting title of the laptop
name = driver.find_elements(By.XPATH, '//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in name[0:10]:
    title.append(i.text)
    
# Extracting rating of the laptop
star = driver.find_elements(By.XPATH,'//div[@class="a-row a-size-small"]')
for i in star[0:10]:
    rating.append(i.text)
    
# # Extracting price of the laptop
Price = driver.find_elements(By.XPATH, '//span[@class="a-price-whole"]')
for i in Price[0:10]:
    price.append(i.text)
    
print(len(title),len(rating),len(price))
# Out:
# 10 10 10

# %%
df = pd.DataFrame({'Title':title, 'Rating':rating, 'Price':price})
df
# Out:
#                                                Title Rating   Price
# 0  Acer One 14 AMD Ryzen 3 3250U Processor (8GB R...    227  43,990
# 1  Acer Aspire Lite 11th Gen Intel Core i3 Premiu...    302  48,990
# 2  Acer Aspire Lite 11th Gen Intel Core i5 Premiu...    170  47,999
# 3  HP [SmartChoice] 15s, Ryzen 5-5500U, 16GB RAM/...  2,229  24,990
# 4  Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...    144  27,990
# 5  Dell 15 Laptop, Intel Core i3-1115G4 Processor...    396  38,990
# 6  HP Laptop 15s, 11th Gen Intel Core i3-1115G4, ...  1,812  41,990
# 7  Acer Aspire Lite 11th Gen Intel Core i3 Premiu...    302  23,990
# 8  [SmartChoice] Lenovo IdeaPad 3 11th Gen Intel ...    830  34,990
# 9  HP [Smartchoice 14s, 11th Gen Intel Core i3-11...  1,353  35,990

# %% [markdown]
# # Question 8.-

# %%
driver = webdriver.Chrome()

# %%
# Opening the given link
driver.get("https://www.azquotes.com/")

# %%
# Click on Top Quotes
click = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
click.click()

# %%
#Creating Empty List
Quote =[]
Author = []
Type_Of_Quotes = []

#Defining Start and end of the pages
start = 0
end = 10

for page in range(start,end):
    
    # Extractiong Quotes
    quote = driver.find_elements(By.XPATH, '//a[@class="title"]')
    for i in quote:
        Quote.append(i.text)
        
    # Extracting Author
    name = driver.find_elements(By.XPATH, '//div[@class="author"]')
    for i in name:
        Author.append(i.text)
        
    # Extracting Type of quotes
    tags = driver.find_elements(By.XPATH, '//div[@class="tags"]')
    for i in tags:
        Type_Of_Quotes.append(i.text)
        
    # Click on the next button to move to the next page
    next = driver.find_element(By.XPATH, '/html/body/div[1]/div[2]/div/div/div/div[1]/div/div[3]/li[12]/a')
    next.click()
    # Use a time.sleep() to wait for the next page to load
    time.sleep(3)

# %%
print(len(Quote),len(Author),len(Type_Of_Quotes))
# Out:
# 1000 1000 1000

# %%
df = pd.DataFrame({'Quote':Quote, 'Author':Author, 'Type_Of_Quotes':Type_Of_Quotes})
df
# Out:
#                                                  Quote              Author  \
# 0    The essence of strategy is choosing what not t...      Michael Porter
# 1    One cannot and must not try to erase the past ...          Golda Meir
# 2    Patriotism means to stand by the country. It d...  Theodore Roosevelt
# 3    Death is something inevitable. When a man has ...      Nelson Mandela
# 4    You have to love a nation that celebrates its ...        Erma Bombeck
# ..                                                 ...                 ...
# 995  Regret for the things we did can be tempered b...    Sydney J. Harris
# 996  America... just a nation of two hundred millio...  Hunter S. Thompson
# 997  For every disciplined effort there is a multip...            Jim Rohn
# 998  The spiritual journey is individual, highly pe...            Ram Dass
# 999  The mind is not a vessel to be filled but a fi...            Plutarch
#
#                                Type_Of_Quotes
# ...

# %% [markdown]
# # Question 9.-

# %%
driver = webdriver.Chrome()

# %%
#Opening the given link
driver.get("https://www.jagranjosh.com/")

# %%
# Click on Top Quotes
click = driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div/div/div[3]/ul/li[6]/a')
click.click()

# %%
#Opening List of Prime Ministers of India
MinisterList = driver.find_element(By.XPATH,'/html/body/div[2]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
MinisterList.click()

# %%
table = driver.find_element(By.XPATH, "/html/body/div[2]/div[2]/div/div[2]/div/div[1]/div/div/div/div[4]/span/div[3]/table/tbody/tr[1]")
rows = table.find_elements(By.TAG_NAME, "tr")

data = []

for row in rows[1:]:
    cells = row.find_elements(By.TAG_NAME,'td')
    for i in cells:
        data.append(i.text)

name = data[1:90:5]
Born_Dead = data[2:90:5]
Term_of_office = data[3:90:5]
Remark = data [4:90:5]

# %%
print(len(name), len(Born_Dead), len(Term_of_office), len(Remark))
# Out:
# 0 0 0 0

# %% [markdown]
# # Question 10.-

# %%
driver = webdriver.Chrome()

# %%
#Open the naukri.com webpage
driver.get("https://www.motor1.com/")

# %%
#Entering '50 most expensive cars' in the search bar
expensivecar = driver.find_element(By.XPATH,"/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/input")
expensivecar.send_keys('50 most expensive cars')

# %%
# search butten 
search =driver.find_element(By.XPATH,"/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]")
search.click()

# %%
#Click on the post '50 most expensive carsin the world'

post = driver.find_element(By.XPATH, '/html/body/div[10]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a')
post.click()

# %%
# Extracting Car Name
CarName = []

carname = driver.find_elements(By.XPATH, '//h3[@class="subheader"]')
for i in carname[0:50]:
    CarName.append(i.text)
    
# Extracting Car Name
Price = []

price_tags = driver.find_elements(By.TAG_NAME,'strong')
for i in price_tags[0:50]:
    Price.append(i.text)
    
print(len(CarName), len(Price))
# Out:
# 50 50

# %%
df =pd.DataFrame({'CarName':CarName, 'Price':Price})
df
# Out:
#                                CarName                        Price
# 0                  Aston Martin Valour          Price: $1.5 Million
# 1                         McLaren Elva          Price: $1.7 Million
# 2                          Czinger 21C          Price: $1.7 Million
# 3                        Ferrari Monza          Price: $1.7 Million
# 4                   Gordon Murray T.33          Price: $1.7 Million
# 5                    Koenigsegg Gemera          Price: $1.7 Million
# 6                          Zenvo TSR-S          Price: $1.7 Million
# 7                   Hennessey Venom F5          Price: $1.8 Million
# 8                      Bentley Bacalar          Price: $1.9 Million
# 9        Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 10              Bentley Mulliner Batur          Price: $2.0 Million
# 11                        Deus Vayanne          Price: $2.0 Million
# 12                         SSC Tuatara          Price: $2.0 Million
# ...
